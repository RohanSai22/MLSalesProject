# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/dataset.csv")
df["Season"].unique()
df
# Out:
#     Year  Quarter  Season    Sales  market%
# 0   2002        2  Summer   200000    0.340
# 1   2003        1  Winter    78000    0.130
# 2   2003        2  Summer   250000    0.300
# 3   2004        1  Winter    86000    0.140
# 4   2004        2  Summer   300000    0.420
# 5   2005        1  Winter    92000    0.160
# 6   2005        2  Summer   325000    0.470
# 7   2006        1  Winter    87000    0.150
# 8   2006        2  Summer   310000    0.450
# 9   2007        1  Winter    78000    0.130
# 10  2007        2  Summer   386000    0.540
# 11  2008        1  Winter   100000    0.170
# 12  2008        2  Summer   396000    0.340
# 13  2009        1  Winter   120000    0.130
# 14  2009        2  Summer   450000    0.400
# 15  2010        1  Winter   130000    0.100
# 16  2010        2  Summer   500000    0.260
# 17  2011        1  Winter   180000    0.400
# 18  2011        2  Summer   690000    0.300
# 19  2012        1  Winter   200000    0.500
# ...

# %% [markdown]
# **How to compare a string with a type int in pandas**
#
# ---
#
# ```
# (df["Season"]!="Summer") & (df["Quarter"].astype(str).str.contains('2'))
# ```

# %%
df["Season"]=((df["Season"]!="Summer") & (df["Quarter"].astype(str).str.contains('2'))).astype(int)
df
# Out:
#     Year  Quarter  Season    Sales  market%
# 0   2002        2       0   200000    0.340
# 1   2003        1       0    78000    0.130
# 2   2003        2       0   250000    0.300
# 3   2004        1       0    86000    0.140
# 4   2004        2       0   300000    0.420
# 5   2005        1       0    92000    0.160
# 6   2005        2       0   325000    0.470
# 7   2006        1       0    87000    0.150
# 8   2006        2       0   310000    0.450
# 9   2007        1       0    78000    0.130
# 10  2007        2       0   386000    0.540
# 11  2008        1       0   100000    0.170
# 12  2008        2       0   396000    0.340
# 13  2009        1       0   120000    0.130
# 14  2009        2       0   450000    0.400
# 15  2010        1       0   130000    0.100
# 16  2010        2       0   500000    0.260
# 17  2011        1       0   180000    0.400
# 18  2011        2       0   690000    0.300
# 19  2012        1       0   200000    0.500
# ...

# %%
df.drop(axis=1,columns=["market%"],inplace=True)
df
# Out:
#     Year  Quarter  Season    Sales
# 0   2002        2       0   200000
# 1   2003        1       0    78000
# 2   2003        2       0   250000
# 3   2004        1       0    86000
# 4   2004        2       0   300000
# 5   2005        1       0    92000
# 6   2005        2       0   325000
# 7   2006        1       0    87000
# 8   2006        2       0   310000
# 9   2007        1       0    78000
# 10  2007        2       0   386000
# 11  2008        1       0   100000
# 12  2008        2       0   396000
# 13  2009        1       0   120000
# 14  2009        2       0   450000
# 15  2010        1       0   130000
# 16  2010        2       0   500000
# 17  2011        1       0   180000
# 18  2011        2       0   690000
# 19  2012        1       0   200000
# 20  2012        2       0   780000
# 21  2013        1       0   220000
# 22  2013        2       0   891092
# 23  2014        1       0   147893
# 24  2014        2       0   919090
# 25  2015        1       0   102044
# ...

# %%
plt.hist(df[df["Season"]==1]["Sales"],color="red",label="Summer")
plt.hist(df[df["Season"]==0]["Sales"],color="blue",label="Winter")
plt.title("Sales")
plt.ylabel("Sales")
plt.xlabel("Year")
plt.legend()
plt.show()

# %%
x=df["Year"]
y=df["Season"]==1
z=df["Season"]==0
df2=pd.DataFrame(df,columns=["Year","Season","Sales"])
df2.plot(x="Year",y="Sales",xlabel="Year",ylabel="Sales",title="Sales in Million",color="green",kind="line")
# Out:
# <Axes: title={'center': 'Sales in Million'}, xlabel='Year', ylabel='Sales'>

# %%
def divide(dataframe):
  x=dataframe[dataframe.columns[:-1]].values
  y=dataframe[dataframe.columns[-1]].values
  print(x)
  print(y)
  return x,y

# %%
x,y=np.split(df,[int(0.6*len(df))])
x_train,y_train=divide(x)
x_test,y_test=divide(y)
# Out:
# [[2002    2    0]
#  [2003    1    0]
#  [2003    2    0]
#  [2004    1    0]
#  [2004    2    0]
#  [2005    1    0]
#  [2005    2    0]
#  [2006    1    0]
#  [2006    2    0]
#  [2007    1    0]
#  [2007    2    0]
#  [2008    1    0]
#  [2008    2    0]
#  [2009    1    0]
#  [2009    2    0]
#  [2010    1    0]
#  [2010    2    0]
#  [2011    1    0]
#  [2011    2    0]
#  [2012    1    0]
#  [2012    2    0]
#  [2013    1    0]]
# [200000  78000 250000  86000 300000  92000 325000  87000 310000  78000
#  386000 100000 396000 120000 450000 130000 500000 180000 690000 200000
#  780000 220000]
# [[2013    2    0]
#  [2014    1    0]
#  [2014    2    0]
#  [2015    1    0]
#  [2015    2    0]
#  [2016    1    0]
#  [2016    2    0]
#  [2017    1    0]
#  [2017    2    0]
#  [2018    1    0]
#  [2018    2    0]
#  [2019    1    0]
#  [2019    2    0]
#  [2020    1    0]
#  [2020    2    0]]
# [ 891092  147893  919090  102044  930000   99030  900010  127320  929783
# ...

# %%
#from sklearn.neighbors import kNeighborsClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.linear_model import LinearRegression

# %%
'''from sklearn import neighbors
kn_model=KNeighborsClassifier(n_neighbors=8)
kn_model.fit(x_train,y_train)'''
# Out:
# KNeighborsClassifier(n_neighbors=8)

# %%
'''y_pred=kn_model.predict(x_test)
print(y_pred)(knn Fails miserabily)'''
# Out:
# [130000 120000 130000 120000 130000 120000 130000 120000 130000 120000
#  130000 120000 130000 120000 130000]

# %%
lin= LinearRegression()
linreg = lin.fit(x_train, y_train)
y_predicted = linreg.predict(x_test)
print(y_predicted)
# Out:
# [612109.09090909 319745.45454545 644627.27272727 352263.63636364
#  677145.45454545 384781.81818182 709663.63636364 417300.
#  742181.81818182 449818.18181819 774700.         482336.36363637
#  807218.18181819 514854.54545455 839736.36363637]

# %%
print(y_test)
# Out:
# [ 891092  147893  919090  102044  930000   99030  900010  127320  929783
#   176367  898360  192863 1020187  282783  928793]
